# %%
# LFW
import os

from shutil import copyfile
from os.path import join
lfw_path = join('./','buf_data','lfw-deepfunneled/')
sub_dirs = [join(lfw_path,d) for d in os.listdir(lfw_path) if os.path.isdir(join(lfw_path,d)) ]

# 
index = 1
jpg_files = []
for d in sub_dirs:
    img_path = [join(d,sd) for sd in os.listdir(d)]
    jpg_path = [path for path in img_path if os.path.isfile(path) and path.endswith('.jpg')]
    for path in jpg_path:
        jpg_files.append(path)


train_dir = join('./','lfw','trainA')
test_dir = join('./','lfw','testA')
root_dir = join('./','lfw')
if not os.path.isdir(root_dir):
    os.mkdir(root_dir)
if not os.path.isdir(train_dir):
    os.mkdir(train_dir)
if not os.path.isdir(test_dir):
    os.mkdir(test_dir)
N = len(jpg_files)
test_count = N // 10
train_count = N - test_count

# train
for i,jpg_path in enumerate(jpg_files[:train_count]):
    path = join(train_dir,'%d.jpg'%i)
    copyfile(jpg_path, path)
    
# test
for i,jpg_path in enumerate(jpg_files[train_count:]):
    path = join(test_dir,'%d.jpg'%i)
    copyfile(jpg_path, path)
print 'Done'
#     for img_path in os.listdir(d)
# Out:
# Done

# %%
from shutil import copyfile
train_dir = join('./','lfw','trainA')
test_dir = join('./','lfw','testA')
root_dir = join('./','lfw')
if not os.path.isdir(root_dir):
    os.mkdir(root_dir)
if not os.path.isdir(train_dir):
    os.mkdir(train_dir)
if not os.path.isdir(test_dir):
    os.mkdir(test_dir)
N = len(jpg_files)
test_count = N // 10
train_count = N - test_count

# train
for i,jpg_path in enumerate(jpg_files[:train_count]):
    path = join(train_dir,'%d.jpg'%i)
    copyfile(jpg_path, path)
    
# test
for i,jpg_path in enumerate(jpg_files[train_count:]):
    path = join(test_dir,'%d.jpg'%i)
    copyfile(jpg_path, path)
print 'Done'
#     for img_path in os.listdir(d)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-cea261f0f92c> in <module>()
#       9 if not os.path.isdir(test_dir):
#      10     os.mkdir(test_dir)
# ---> 11 N = len(jpg_files)
#      12 test_count = N // 10
#      13 train_count = N - test_count
#
# NameError: name 'jpg_files' is not defined

# %%
# Emoji
import os
import cv2
from os.path import join
emoji_path = join('./','buf_data','EmojiOne_3.1.1_128x128_filted')
jpg_files = [join(emoji_path,d) for d in os.listdir(emoji_path) if os.path.isfile(join(emoji_path,d)) and d.endswith('.png') ]


#         
#     
# 
train_dir = join('./','emoji','trainB')
test_dir = join('./','emoji','testB')
root_dir = join('./','emoji')
if not os.path.isdir(root_dir):
    os.mkdir(root_dir)
if not os.path.isdir(train_dir):
    os.mkdir(train_dir)
if not os.path.isdir(test_dir):
    os.mkdir(test_dir)
N = len(jpg_files)

test_count = N // 10
train_count = N - test_count

# train
for i,jpg_path in enumerate(jpg_files[:train_count]):
    path = join(train_dir,'%d.jpg'%i)
    # convert to jpg
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
    
# test
for i,jpg_path in enumerate(jpg_files[train_count:]):
    path = join(test_dir,'%d.jpg'%i)
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
print 'Done'
# Out:
# Done

# %%
# president
import os
import cv2
from os.path import join
emoji_path = join('./','buf_data','president')
jpg_files = [join(emoji_path,d) for d in os.listdir(emoji_path) if os.path.isfile(join(emoji_path,d)) and d.endswith('.jpg') ]
print jpg_files

#         
#     
# 
train_dir = join('./','face2president','trainB')
test_dir = join('./','face2president','testB')
root_dir = join('./','face2president')
if not os.path.isdir(root_dir):
    os.mkdir(root_dir)
if not os.path.isdir(train_dir):
    os.mkdir(train_dir)
if not os.path.isdir(test_dir):
    os.mkdir(test_dir)
N = len(jpg_files)

test_count = N // 10
train_count = N - test_count

# train
for i,jpg_path in enumerate(jpg_files[:train_count]):
    path = join(train_dir,'%d.jpg'%i)
    # convert to jpg
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
    
# test
for i,jpg_path in enumerate(jpg_files[train_count:]):
    path = join(test_dir,'%d.jpg'%i)
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
print 'Done'
# Out:
# ['./buf_data/face/1318.jpg', './buf_data/face/2911.jpg', './buf_data/face/626.jpg', './buf_data/face/1602.jpg', './buf_data/face/1363.jpg', './buf_data/face/409.jpg', './buf_data/face/2647.jpg', './buf_data/face/1393.jpg', './buf_data/face/1691.jpg', './buf_data/face/2330.jpg', './buf_data/face/2528.jpg', './buf_data/face/18.jpg', './buf_data/face/2444.jpg', './buf_data/face/2177.jpg', './buf_data/face/2257.jpg', './buf_data/face/1728.jpg', './buf_data/face/833.jpg', './buf_data/face/908.jpg', './buf_data/face/27.jpg', './buf_data/face/357.jpg', './buf_data/face/808.jpg', './buf_data/face/365.jpg', './buf_data/face/48.jpg', './buf_data/face/66.jpg', './buf_data/face/2435.jpg', './buf_data/face/2105.jpg', './buf_data/face/
', './buf_data/face/618.jpg', './buf_data/face/1260.jpg', './buf_data/face/2975.jpg', './buf_data/face/1008.jpg', './buf_data/face/740.jpg', './buf_data/face/83.jpg', './buf_data/face/1901.jpg', './buf_data/face/1771.jpg', './buf_data/face/2696.jpg', './buf_data/face/1441.jpg', './buf_data/face/172.jpg', './buf_data/face/330.jpg', './buf_data/face/2936.jpg', './buf_data/face/926.jpg', './buf_data/face/1873.jpg', './buf_data/face/1050.jpg', './buf_data/face/1725.jpg', './buf_data/face/1529.jpg', './buf_data/face/898.jpg', './buf_data/face/2663.jpg', './buf_data/face/1121.jpg', './buf_data/face/1751.jpg', './buf_data/face/1749.jpg', './buf_data/face ...
# Done

# %%
# president
import os
import cv2
from os.path import join
emoji_path = join('./','buf_data','president')
jpg_files = [join(emoji_path,d) for d in os.listdir(emoji_path) if os.path.isfile(join(emoji_path,d)) and d.endswith('.jpg') ]
print len(jpg_files)

#         
#     
# 
root_dir = join('./','president2coach')
train_dir = join(root_dir,'trainA')
test_dir = join(root_dir,'testA')
if not os.path.isdir(root_dir):
    os.mkdir(root_dir)
if not os.path.isdir(train_dir):
    os.mkdir(train_dir)
if not os.path.isdir(test_dir):
    os.mkdir(test_dir)
N = len(jpg_files)

test_count = N // 10
train_count = N - test_count

# train
for i,jpg_path in enumerate(jpg_files[:train_count]):
    path = join(train_dir,'%d.jpg'%i)
    # convert to jpg
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
    
# test
for i,jpg_path in enumerate(jpg_files[train_count:]):
    path = join(test_dir,'%d.jpg'%i)
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
print 'Done'
# Out:
# 9720
# Done

# %%
# coach
import os
import cv2
from os.path import join
emoji_path = join('./','buf_data','fit_coach')
jpg_files = [join(emoji_path,d) for d in os.listdir(emoji_path) if os.path.isfile(join(emoji_path,d)) and d.endswith('.jpg') ]
print len(jpg_files)

#         
#     
# 
root_dir = join('./','fit_coach')
train_dir = join(root_dir,'trainB')
test_dir = join(root_dir,'testB')
if not os.path.isdir(root_dir):
    os.mkdir(root_dir)
if not os.path.isdir(train_dir):
    os.mkdir(train_dir)
if not os.path.isdir(test_dir):
    os.mkdir(test_dir)
N = len(jpg_files)

test_count = N // 10
train_count = N - test_count

# train
for i,jpg_path in enumerate(jpg_files[:train_count]):
    path = join(train_dir,'%d.jpg'%i)
    # convert to jpg
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
    
# test
for i,jpg_path in enumerate(jpg_files[train_count:]):
    path = join(test_dir,'%d.jpg'%i)
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
print 'Done'
# Out:
# OSErrorTraceback (most recent call last)
# <ipython-input-1-6af9dff11c86> in <module>()
#       4 from os.path import join
#       5 emoji_path = join('./','buf_data','fit_coach')
# ----> 6 jpg_files = [join(emoji_path,d) for d in os.listdir(emoji_path) if os.path.isfile(join(emoji_path,d)) and d.endswith('.jpg') ]
#       7 print len(jpg_files)
#       8
#
# OSError: [Errno 2] No such file or directory: './buf_data/fit_coach'

# %%
# annie
import os
import cv2
from os.path import join
emoji_path = join('./','buf_data','annie')
jpg_files = [join(emoji_path,d) for d in os.listdir(emoji_path) if os.path.isfile(join(emoji_path,d)) and d.endswith('.jpg') ]
print len(jpg_files)

#         
#     
# 
root_dir = join('./','annie')
train_dir = join(root_dir,'trainA')
test_dir = join(root_dir,'testA')
if not os.path.isdir(root_dir):
    os.mkdir(root_dir)
if not os.path.isdir(train_dir):
    os.mkdir(train_dir)
if not os.path.isdir(test_dir):
    os.mkdir(test_dir)
N = len(jpg_files)

test_count = N // 10
train_count = N - test_count

# train
for i,jpg_path in enumerate(jpg_files[:train_count]):
    path = join(train_dir,'%d.jpg'%i)
    # convert to jpg
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
    
# test
for i,jpg_path in enumerate(jpg_files[train_count:]):
    path = join(test_dir,'%d.jpg'%i)
    img = cv2.imread(jpg_path)
    cv2.imwrite(path, img)
    
print 'Done'
# Out:
# 1426
# Done
